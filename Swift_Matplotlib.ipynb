// %% [markdown]
// <a href="https://colab.research.google.com/github/zaidalyafeai/Swift4TF/blob/master/Swift_Matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

// %%
//let us try cv2 
import Python

// %%
let cv2 = Python.import("cv2")
let plt = Python.import("matplotlib.pyplot")

// %%
%include "EnableIPythonDisplay.swift"
IPythonDisplay.shell.enable_matplotlib("inline")
// Out:
// ('inline', 'module://ipykernel.pylab.backend_inline')

// %%
let image = cv2.imread("cat.png")

// %%
let z = plt.imshow(image)
let w = plt.show()
