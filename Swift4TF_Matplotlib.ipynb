// %% [markdown]
// Allow showing inline Images

// %%
%include "EnableIPythonDisplay.swift"
IPythonDisplay.shell.enable_matplotlib("inline")
// Out:
// ('inline', 'module://ipykernel.pylab.backend_inline')

// %% [markdown]
// Import python and some libraries

// %%
import Python

// %%
let np = Python.import("numpy")
let plt = Python.import("matplotlib.pyplot")
let subprocess = Python.import("subprocess")
let pil = Python.import("PIL")

// %% [markdown]
// Download the image

// %%
let command = "wget https://images.pexels.com/photos/617278/pexels-photo-617278.jpeg -O cat.png"
subprocess.call(command, shell: true)
// Out:
// --2019-06-13 16:08:49--  https://images.pexels.com/photos/617278/pexels-photo-617278.jpeg
// Resolving images.pexels.com (images.pexels.com)... 104.17.209.102, 104.17.208.102, 2606:4700::6811:d166, ...
// Connecting to images.pexels.com (images.pexels.com)|104.17.209.102|:443... connected.
// HTTP request sent, awaiting response... 200 OK
// Length: 8661863 (8.3M) [image/jpeg]
// Saving to: ‘cat.png’
//
// cat.png             100%[===================>]   8.26M  --.-KB/s    in 0.1s
//
// 2019-06-13 16:08:49 (79.3 MB/s) - ‘cat.png’ saved [8661863/8661863]
// 0

// %% [markdown]
// Plot the image

// %%
let img = pil.Image.open("cat.png")
print(np.array(img).shape)
plt.imshow(np.array(img))
plt.show()
// Out:
// (3264, 4928, 3)
// None
